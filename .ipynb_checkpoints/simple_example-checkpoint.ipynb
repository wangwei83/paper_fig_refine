# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn
from __future__ import division
import pandas as pd

plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签\n
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号

# %%
df = pd.read_csv('./data_df.csv')

# %%
plt.figure (figsize= (12, 8))
plt.xlabel("时间轴",fontsize=15)
plt.ylabel("传感器数值（瓦，伏，安等）",fontsize=15)
plt.plot(df['0'])
plt.scatter(80,-25,c = 'r',marker = 'o')

plt.scatter(232,0,c = 'r',marker = 'o')

plt.scatter(363,0,c = 'r',marker = 'o')

plt.scatter(507,-4,c = 'r',marker = 'o')

plt.scatter(810,0,c = 'r',marker = 'o')
