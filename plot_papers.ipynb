# %%
import matplotlib.pyplot as plt
import pandas as pd
plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签\n
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号

# %%
df = pd.read_csv('./papers.csv')

# %%
plt.figure(figsize=(10,8))
plt.xlabel("年份",fontsize=15)
plt.ylabel("文献数量",fontsize=15)
# plt.stem(df.year[:-1], df.num[:-1])
plt.plot(df.year[:-1], df.num[:-1],'g^')
plt.plot(df.year[:-1], df.num[:-1],'-.')

# plt.plot(df.year[-1],df.num[-1],'g')

plt.scatter(2021,175)


# plt.legend('number',loc = 'center')

plt.axhline(15,linewidth=1,linestyle='-.',color='y')
plt.axvline(2010,linewidth=1,linestyle='-.',color='g')

plt.axhline(80,linewidth=1,linestyle='-.',color='r')
plt.axvline(2015,linewidth=1,linestyle='-.',color='b')

plt.axvline(2021,linestyle='-.',color='black')

# plt.grid()
plt.savefig("papercurve.png", dpi=600, bbox_inches='tight')

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10,8))

ax.set_xlabel("年份",fontsize=15)
ax.set_ylabel("文献数量（篇）",fontsize=15)

ax.plot(df.year[:-1], df.num[:-1],'b-o',label='历史数据')

xx = [2020,2021,2022]
yy = [125,175,180]
ax.plot(xx,yy,'b-.^',label='估计数据')
ax.legend(loc='upper center',fontsize=15)

ax.axhline(15,linewidth=1,linestyle='-.',color='darkorange')
ax.axvline(2010,linewidth=1,linestyle='-.',color='b')

ax.axhline(80,linewidth=1,linestyle='-.',color='darkorange')
ax.axvline(2015,linewidth=1,linestyle='-.',color='b')

ax.annotate(" 80篇",
            xy=(2023, 80), xycoords='data',
            xytext=(2026, 80), textcoords='data',
            size=15, va="center", ha="center",
            arrowprops=dict(facecolor='black', shrink=0.05),
            )
ax.annotate(" 15篇",
            xy=(2023, 15), xycoords='data',
            xytext=(2026, 15), textcoords='data',
            size=15, va="center", ha="center",
            arrowprops=dict(facecolor='black', shrink=0.05),
            )

plt.text(1990, 8, r'缓慢发展期',fontsize=12)
plt.text(2010.2, 70, r'快速增长期',fontsize=12)
plt.text(2018, 100, r'高速发展期',fontsize=12)


plt.axvspan(1988, 2010, facecolor='0.99', alpha=0.5)
plt.axvspan(2010, 2015, facecolor='0.9', alpha=0.5)
plt.axvspan(2015, 2022, facecolor='0.65', alpha=0.5)


plt.savefig("papercurve0921.png", dpi=600, bbox_inches='tight')

# %%
# 准备增加刻度

import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10,8))

ax.set_xlabel("年份",fontsize=15)
ax.set_ylabel("文献数量（篇）",fontsize=15)

ax.plot(df.year[:-1], df.num[:-1],'b-o',label='历史数据')

xx = [2020,2021,2022]
yy = [125,175,180]
ax.plot(xx,yy,'b-.^',label='估计数据')
ax.legend(loc='upper center',fontsize=15)

ax.axhline(15,linewidth=1,linestyle='-.',color='darkorange')
ax.axvline(2010,linewidth=1,linestyle='-.',color='b')

ax.axhline(80,linewidth=1,linestyle='-.',color='darkorange')
ax.axvline(2015,linewidth=1,linestyle='-.',color='b')


ax.annotate("机器学习",
            xy=(2022, 80), xycoords='data',
            xytext=(2026, 80), textcoords='data',
            size=15, va="center", ha="center",
            arrowprops=dict(facecolor='black', shrink=0.05),
            )
ax.annotate("高级计量",
            xy=(2022, 15), xycoords='data',
            xytext=(2026, 15), textcoords='data',
            size=15, va="center", ha="center",
            arrowprops=dict(facecolor='black', shrink=0.05),
            )

plt.text(1990, 8, r'缓慢发展期',fontsize=12)
plt.text(2010.2, 70, r'快速增长期',fontsize=12)
plt.text(2018, 100, r'高速发展期',fontsize=12)

plt.axvspan(1988, 2010, facecolor='0.99', alpha=0.5)
plt.axvspan(2010, 2015, facecolor='0.9', alpha=0.5)
plt.axvspan(2015, 2022, facecolor='0.65', alpha=0.5)

plt.savefig("papercurve0921ml-ami.png", dpi=600, bbox_inches='tight')

# %%
df_cjh = pd.read_csv('./papers-cjh.csv')
df_cjh_ai = pd.read_csv('./papers-cjh-ai.csv')
df_cjh_chinese = pd.read_csv('./papers-cjh-chinese.csv')

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator, FormatStrFormatter

fig, ax = plt.subplots(figsize=(10,8))

ax.set_xlabel("Year",fontsize=15)
ax.set_ylabel("Numbers of papers",fontsize=15)

ax.plot(df_cjh.year, df_cjh.num,'b-o',label='Total numbers of papers')
ax.plot(df_cjh_ai.year, df_cjh_ai.num,'r-o',label='Numbers of paper based on AI')
ax.plot(df_cjh_chinese.year, df_cjh_chinese.num,'g-o',label='Numbers of papers from China')

ax.legend(loc='upper left',fontsize=15)



# 设置 x 轴的刻度为整数
ax.xaxis.set_major_locator(MultipleLocator(1))
ax.xaxis.set_major_formatter(FormatStrFormatter('%d'))

plt.savefig("paper-cjh-ai-chinese-all.png", dpi=600, bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator, FormatStrFormatter

fig, ax = plt.subplots(figsize=(10,8))

ax.set_xlabel("Year",fontsize=15)
ax.set_ylabel("Numbers of papers",fontsize=15)

ax.plot(df_cjh.year, df_cjh.num,'b-o',label='Total numbers of papers')
ax.plot(df_cjh_ai.year, df_cjh_ai.num,'r-o',label='Numbers of papers based on AI')
ax.plot(df_cjh_chinese.year, df_cjh_chinese.num,'g-o',label='Numbers of papers from China')

ax.legend(loc='upper left',fontsize=15)



# 设置 x 轴的刻度为整数
ax.xaxis.set_major_locator(MultipleLocator(1))
ax.xaxis.set_major_formatter(FormatStrFormatter('%d'))


plt.axvspan(2004, 2015, facecolor='0.99', alpha=0.5)
plt.axvspan(2015, 2020, facecolor='0.9', alpha=0.5)
plt.axvspan(2020, 2024, facecolor='0.65', alpha=0.5)

ax.axhline(5,linewidth=1,linestyle='-.',color='darkorange')
ax.axvline(2015,linewidth=1,linestyle='-.',color='b')

# ax.axhline(30,linewidth=1,linestyle='-.',color='darkorange')
ax.axvline(2020,linewidth=1,linestyle='-.',color='b')

# ax.annotate("机器学习",
#             xy=(2024, 30), xycoords='data',
#             xytext=(2028, 30), textcoords='data',
#             size=15, va="center", ha="center",
#             arrowprops=dict(facecolor='black', shrink=0.05),
#             )
# ax.annotate("高级计量",
#             xy=(2024, 5), xycoords='data',
#             xytext=(2028, 5), textcoords='data',
#             size=15, va="center", ha="center",
#             arrowprops=dict(facecolor='black', shrink=0.05),
#             )

plt.savefig("paper-cjh-ai-chinese-all-gai.png", dpi=600, bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import MultipleLocator, FormatStrFormatter
import textwrap
# 数据
categories = ['System', 'Computer assisted language learning', 'Frontiers in psychology', 'Innovation in Language Learning and Teaching', 'Computers & education', 'Applied Linguistics']
ca     = [1,2,3,4,5,6]
values = [9, 4, 4, 3, 3, 3]

# 创建图表
fig, ax = plt.subplots(figsize=(15, 8))

# 绘制柱状图
bars = ax.bar(ca, values,width=0.5)

# 添加标题和标签
# ax.set_title('示例柱状图')
# ax.set_xlabel('类别') 'color': 'darkred'
ax.set_ylabel('Numbers of papers', fontsize=15, color='black') 

# 在每个柱子顶部标注类别名称，使用 textwrap 模块处理文本换行
for bar, category in zip(bars, categories):
    wrapped_text = "\n".join(textwrap.wrap(category, width=12))
    ax.text(bar.get_x() + bar.get_width() / 2, -3, wrapped_text, ha='center', va='bottom', fontsize=15,fontdict={'family': 'serif', 'color': 'black', 'weight': 'bold'})


# 显示图表
# plt.show()
plt.savefig("paper-cjh-publication.png", dpi=600, bbox_inches='tight')
